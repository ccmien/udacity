# %% [markdown]
# Deep Learning
# =============
#
# Assignment 5
# ------------
#
# The goal of this assignment is to train a Word2Vec skip-gram model over [Text8](http://mattmahoney.net/dc/textdata) data.

# %%
# These are all the modules we'll be using later. Make sure you can import them
# before proceeding further.
# %matplotlib inline
from __future__ import print_function
import collections
import math
import numpy as np
import os
import random
import tensorflow as tf
import zipfile
from matplotlib import pylab
from six.moves import range
from six.moves.urllib.request import urlretrieve
from sklearn.manifold import TSNE

# %% [markdown]
# Download the data from the source website if necessary.

# %%
url = 'http://mattmahoney.net/dc/'

def maybe_download(filename, expected_bytes):
  """Download a file if not present, and make sure it's the right size."""
  if not os.path.exists(filename):
    filename, _ = urlretrieve(url + filename, filename)
  statinfo = os.stat(filename)
  if statinfo.st_size == expected_bytes:
    print('Found and verified %s' % filename)
  else:
    print(statinfo.st_size)
    raise Exception(
      'Failed to verify ' + filename + '. Can you get to it with a browser?')
  return filename

filename = maybe_download('text8.zip', 31344016)
# Out:
# Found and verified text8.zip

# %% [markdown]
# Read the data into a string.

# %%
def read_data(filename):
  """Extract the first file enclosed in a zip file as a list of words"""
  with zipfile.ZipFile(filename) as f:
    data = tf.compat.as_str(f.read(f.namelist()[0])).split()
  return data
  
words = read_data(filename)
print('Data size %d' % len(words))
# Out:
# Data size 17005207

# %% [markdown]
# Build the dictionary and replace rare words with UNK token.

# %%
vocabulary_size = 50000

def build_dataset(words):
  count = [['UNK', -1]]
  count.extend(collections.Counter(words).most_common(vocabulary_size - 1))
  dictionary = dict()
  for word, _ in count:
    dictionary[word] = len(dictionary)
  data = list()
  unk_count = 0
  for word in words:
    if word in dictionary:
      index = dictionary[word]
    else:
      index = 0  # dictionary['UNK']
      unk_count = unk_count + 1
    data.append(index)
  count[0][1] = unk_count
  reverse_dictionary = dict(zip(dictionary.values(), dictionary.keys()))
  return data, count, dictionary, reverse_dictionary

data, count, dictionary, reverse_dictionary = build_dataset(words)
print('Most common words (+UNK)', count[:5])
print('Sample data', data[:10])
del words  # Hint to reduce memory.

# %% [markdown]
# Function to generate a training batch for the skip-gram model.

# %%
data_index = 0

def generate_batch(batch_size, num_skips, skip_window):
  global data_index
  assert batch_size % num_skips == 0
  assert num_skips <= 2 * skip_window
  batch = np.ndarray(shape=(batch_size), dtype=np.int32)
  labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
  span = 2 * skip_window + 1 # [ skip_window target skip_window ]
  buffer = collections.deque(maxlen=span)
  for _ in range(span):
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  for i in range(batch_size // num_skips):
    target = skip_window  # target label at the center of the buffer
    targets_to_avoid = [ skip_window ]
    for j in range(num_skips):
      while target in targets_to_avoid:
        target = random.randint(0, span - 1)
      targets_to_avoid.append(target)
      batch[i * num_skips + j] = buffer[skip_window]
      labels[i * num_skips + j, 0] = buffer[target]
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  return batch, labels

print('data:', [reverse_dictionary[di] for di in data[:8]])

for num_skips, skip_window in [(2, 1), (4, 2)]:
    data_index = 0
    batch, labels = generate_batch(batch_size=8, num_skips=num_skips, skip_window=skip_window)
    print('\nwith num_skips = %d and skip_window = %d:' % (num_skips, skip_window))
    print('    batch:', [reverse_dictionary[bi] for bi in batch])
    print('    labels:', [reverse_dictionary[li] for li in labels.reshape(8)])
# Out:
# data: ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first']
#
# with num_skips = 2 and skip_window = 1:
#     batch: ['originated', 'originated', 'as', 'as', 'a', 'a', 'term', 'term']
#     labels: ['as', 'anarchism', 'a', 'originated', 'as', 'term', 'a', 'of']
#
# with num_skips = 4 and skip_window = 2:
#     batch: ['as', 'as', 'as', 'as', 'a', 'a', 'a', 'a']
#     labels: ['term', 'a', 'anarchism', 'originated', 'of', 'originated', 'as', 'term']

# %% [markdown]
# Train a skip-gram model.

# %%
batch_size = 128
embedding_size = 128 # Dimension of the embedding vector.
skip_window = 1 # How many words to consider left and right.
num_skips = 2 # How many times to reuse an input to generate a label.
# We pick a random validation set to sample nearest neighbors. here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent. 
valid_size = 16 # Random set of words to evaluate similarity on.
valid_window = 100 # Only pick dev samples in the head of the distribution.
valid_examples = np.array(random.sample(range(valid_window), valid_size))
num_sampled = 64 # Number of negative examples to sample.

graph = tf.Graph()

with graph.as_default(), tf.device('/cpu:0'):

  # Input data.
  train_dataset = tf.placeholder(tf.int32, shape=[batch_size])
  train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
  valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
  
  # Variables.
  embeddings = tf.Variable(
    tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
  softmax_weights = tf.Variable(
    tf.truncated_normal([vocabulary_size, embedding_size],
                         stddev=1.0 / math.sqrt(embedding_size)))
  softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))
  
  # Model.
  # Look up embeddings for inputs.
  embed = tf.nn.embedding_lookup(embeddings, train_dataset)
  # Compute the softmax loss, using a sample of the negative labels each time.
  loss = tf.reduce_mean(
    tf.nn.sampled_softmax_loss(softmax_weights, softmax_biases, embed,
                               train_labels, num_sampled, vocabulary_size))

  # Optimizer.
  # Note: The optimizer will optimize the softmax_weights AND the embeddings.
  # This is because the embeddings are defined as a variable quantity and the
  # optimizer's `minimize` method will by default modify all variable quantities 
  # that contribute to the tensor it is passed.
  # See docs on `tf.train.Optimizer.minimize()` for more details.
  optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)
  
  # Compute the similarity between minibatch examples and all embeddings.
  # We use the cosine distance:
  norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
  normalized_embeddings = embeddings / norm
  valid_embeddings = tf.nn.embedding_lookup(
    normalized_embeddings, valid_dataset)
  similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))

# %%
num_steps = 100001

with tf.Session(graph=graph) as session:
  tf.initialize_all_variables().run()
  print('Initialized')
  average_loss = 0
  for step in range(num_steps):
    batch_data, batch_labels = generate_batch(
      batch_size, num_skips, skip_window)
    feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
    _, l = session.run([optimizer, loss], feed_dict=feed_dict)
    average_loss += l
    if step % 2000 == 0:
      if step > 0:
        average_loss = average_loss / 2000
      # The average loss is an estimate of the loss over the last 2000 batches.
      print('Average loss at step %d: %f' % (step, average_loss))
      average_loss = 0
    # note that this is expensive (~20% slowdown if computed every 500 steps)
    if step % 10000 == 0:
      sim = similarity.eval()
      for i in range(valid_size):
        valid_word = reverse_dictionary[valid_examples[i]]
        top_k = 8 # number of nearest neighbors
        nearest = (-sim[i, :]).argsort()[1:top_k+1]
        log = 'Nearest to %s:' % valid_word
        for k in range(top_k):
          close_word = reverse_dictionary[nearest[k]]
          log = '%s %s,' % (log, close_word)
        print(log)
  final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step 0: 8.198005
# Nearest to all: nonaligned, congregation, eithne, horror, abdicating, alterations, maximian, halos,
# Nearest to years: stencil, bottom, mussels, melchior, caf, pursue, agassiz, emotive,
# Nearest to such: requests, hawick, lefebvre, alleviated, charlottetown, sixty, fg, chambers,
# Nearest to about: libra, recurrence, plenty, narratives, refugee, alfred, gs, translucent,
# Nearest to that: niels, chissano, fisa, hereby, halfwidth, connected, samson, elwood,
# Nearest to or: pound, itis, tenerife, schneier, frick, lass, refused, swedes,
# Nearest to but: redemptive, honour, shek, cultivation, rennet, transcendentalism, alexandrovna, perished,
# Nearest to as: blissymbolics, localized, skinny, kilt, wear, preterist, apologised, apuleius,
# Nearest to time: execute, brock, hancock, ihr, setbacks, colfax, nonexistence, chem,
# Nearest to some: ninth, rightist, erupt, aba, consortium, diaries, spr, rogers,
# Nearest to an: miscarriage, adventurer, build, devises, software, cycladic, wakefulness, raping,
# Nearest to two: stats, setback, clint, marcantonio, forgive, call, matlab, paragraph,
# Nearest to into: crypto, ignites, sanchez, maligned, megas, several, taraki, nibelungenlied,
# Nearest to many: gradualism, zee, lebowski, senado, hooks, homozygous, amtrak, diplomas,
# Nearest to when: afterthought, kaohsiung, asylum, headers, ophile, narn, lumberjack, sephiroth,
# Nearest to no: budgetary, forfeited, lobster, quarter, jinn, exonerated, gomer, evaporative,
# Average loss at step 2000: 4.360880
# Average loss at step 4000: 3.868287
# Average loss at step 6000: 3.785008
# Average loss at step 8000: 3.683079
# Average loss at step 10000: 3.607848
# Nearest to all: precaution, vax, virology, quantifiers, exposure, communions, halos, maximian,
# Nearest to years: mussels, iceberg, issn, pursue, sudan, stencil, steyn, famicom,
# Nearest to such: sixty, phalanx, organism, well, gently, alleviated, hawick, asiatic,
# Nearest to about: refugee, narratives, plenty, libra, alfred, adidas, recurrence, stationery,
# Nearest to that: which, it, hereby, iblis, samson, halfwidth, still, addams,
# Nearest to or: and, asn, bowell, cdf, itis, pound, redemptive, than,
# Nearest to but: redemptive, usually, although, would, shek, hedge, myspace, crystallography,
# Nearest to as: by, furies, apuleius, peebles, wear, serling, lasorda, lauded,
# Nearest to time: ores, revolution, alsatian, veganism, follows, adorned, particles, damasus,
# Nearest to some: many, started, the, commercially, agrarianism, morons, qcd, maeshowe,
# Nearest to an: miscarriage, bulls, build, dewitt, herbicides, rolled, valet, consult,
# Nearest to two: five, three, four, six, eight, nine, seven, zero,
# Nearest to into: ignites, crypto, sniff, taraki, relief, stephane, munich, bernardino,
# Nearest to many: some, cancerous, those, multihulls, zee, any, alds, piece,
# Nearest to when: rts, through, abortions, heinemann, nsc, shareholders, senses, writs,
# Nearest to no: breasts, so, forfeited, exonerated, profess, elizabeth, lawlessness, valuation,
# Average loss at step 12000: 3.604397
# Average loss at step 14000: 3.567780
# Average loss at step 16000: 3.407444
# Average loss at step 18000: 3.455909
# Average loss at step 20000: 3.539409
# Nearest to all: these, vax, many, their, precaution, communions, some, invitational,
# Nearest to years: sudan, mussels, boyars, iceberg, days, centuries, issn, steyn,
# Nearest to such: well, these, known, yalta, phalanx, sixty, organism, asiatic,
# Nearest to about: recurrence, refugee, narratives, plenty, operatic, elect, dramas, coding,
# Nearest to that: which, but, however, hereby, also, whether, inaccurate, samson,
# Nearest to or: and, than, unloaded, allocating, verifying, bowell, with, my,
# Nearest to but: which, although, that, property, usually, and, would, redemptive,
# Nearest to as: blackwell, lifeson, cosa, very, furies, localized, anselm, nestorianism,
# Nearest to time: veganism, ores, revolution, anglo, ozzfest, judaism, particles, adorned,
# Nearest to some: many, these, other, any, most, various, several, ethos,
# Nearest to an: miscarriage, bulls, wakefulness, the, trachea, herbicides, dewitt, rajah,
# Nearest to two: three, four, five, six, one, seven, eight, zero,
# Nearest to into: from, stephane, by, through, with, after, ignites, figurative,
# Nearest to many: some, these, other, various, those, several, cancerous, all,
# Nearest to when: if, through, though, heinemann, nsc, while, whether, writs,
# Nearest to no: breasts, valuation, a, understood, lawlessness, so, carta, budgetary,
# Average loss at step 22000: 3.503995
# Average loss at step 24000: 3.489167
# Average loss at step 26000: 3.479041
# Average loss at step 28000: 3.479885
# Average loss at step 30000: 3.497847
# Nearest to all: these, vax, precaution, both, some, many, several, each,
# Nearest to years: days, centuries, sudan, mussels, people, months, issn, boyars,
# Nearest to such: well, these, known, yalta, sixty, commercial, regional, baka,
# Nearest to about: plenty, emmerdale, operatic, on, coding, elect, affirmed, around,
# Nearest to that: which, this, however, but, when, whether, inaccurate, what,
# Nearest to or: and, than, cdf, nucleotides, conquers, whiskers, ductus, zondervan,
# Nearest to but: although, however, though, while, which, that, and, redemptive,
# Nearest to as: choices, provability, furies, by, milliseconds, wear, entendre, sidon,
# Nearest to time: ores, cod, curbed, handles, veganism, strassburg, whether, rie,
# Nearest to some: many, these, several, various, any, other, the, most,
# Nearest to an: miscarriage, bulls, disciplined, dewitt, journalism, sade, superoxide, adventurer,
# Nearest to two: four, three, one, five, seven, six, eight, nine,
# Nearest to into: from, under, through, stephane, bernardino, with, after, cabbie,
# Nearest to many: some, these, several, various, other, those, most, cancerous,
# Nearest to when: if, while, through, though, where, until, heinemann, before,
# Nearest to no: breasts, any, valuation, understood, budgetary, carta, often, wong,
# Average loss at step 32000: 3.501038
# Average loss at step 34000: 3.494065
# Average loss at step 36000: 3.452779
# Average loss at step 38000: 3.302727
# Average loss at step 40000: 3.432967
# Nearest to all: both, these, each, vax, precaution, origins, hopewell, digging,
# Nearest to years: days, centuries, months, minutes, year, quimby, sudan, pong,
# Nearest to such: well, these, known, yalta, including, commercial, many, comoros,
# Nearest to about: tau, ozarks, florian, on, over, operatic, toward, around,
# Nearest to that: which, this, inaccurate, what, successfully, climatic, however, highlander,
# Nearest to or: and, than, a, obstruct, whiskers, watered, insisting, flattening,
# Nearest to but: however, although, though, and, which, toland, are, placenta,
# Nearest to as: sodium, when, choices, longfellow, nestorianism, lifeson, be, guanosine,
# Nearest to time: rie, day, period, way, mair, year, cod, ores,
# Nearest to some: many, these, several, any, various, uncontroversial, the, pacification,
# Nearest to an: miscarriage, wakefulness, dewitt, rolled, bulls, linguists, elmendorf, nlm,
# Nearest to two: three, four, five, six, seven, eight, one, nine,
# Nearest to into: from, through, stephane, fist, under, buckminsterfullerene, toward, megas,
# Nearest to many: some, several, these, those, various, cancerous, nat, other,
# Nearest to when: if, while, where, though, before, until, through, heinemann,
# Nearest to no: valuation, any, breasts, budgetary, carta, often, nothing, understood,
# Average loss at step 42000: 3.437634
# Average loss at step 44000: 3.454202
# Average loss at step 46000: 3.450001
# Average loss at step 48000: 3.351108
# Average loss at step 50000: 3.390407
# Nearest to all: both, each, ideological, these, every, origins, digging, inroads,
# Nearest to years: days, centuries, months, times, people, minutes, year, date,
# Nearest to such: well, known, these, yalta, many, regarded, baka, novello,
# Nearest to about: on, hadley, around, over, tau, florian, spotting, bisexual,
# Nearest to that: which, however, but, what, dubnium, this, collateral, climatic,
# Nearest to or: and, than, whiskers, though, chrysler, but, aphelion, wenders,
# Nearest to but: however, although, though, and, toland, when, while, that,
# Nearest to as: furies, kekul, nestorianism, aspiring, kryptonians, is, lifeson, cosa,
# Nearest to time: year, day, period, prophecy, rie, desk, cod, hava,
# Nearest to some: many, these, several, various, those, their, any, both,
# Nearest to an: miscarriage, wakefulness, bulls, trachea, elmendorf, rolled, hamid, dewitt,
# Nearest to two: three, four, six, eight, one, seven, five, nine,
# Nearest to into: through, from, under, toward, bernardino, fist, megas, on,
# Nearest to many: some, several, various, these, those, both, other, scholars,
# Nearest to when: if, while, after, where, before, although, though, until,
# Nearest to no: any, valuation, budgetary, carta, hmg, biafra, motels, chessboard,
# Average loss at step 52000: 3.433550
# Average loss at step 54000: 3.425822
# Average loss at step 56000: 3.433954
# Average loss at step 58000: 3.399423
# Average loss at step 60000: 3.392717
# Nearest to all: both, any, these, most, those, many, some, each,
# Nearest to years: days, months, centuries, times, minutes, year, weeks, decades,
# Nearest to such: known, well, these, many, yalta, including, some, commercial,
# Nearest to about: around, over, on, emigr, ozarks, filtering, cock, striping,
# Nearest to that: which, what, this, however, climatic, successfully, often, who,
# Nearest to or: and, than, whiskers, like, aphelion, but, marcia, dilemma,
# Nearest to but: however, although, and, though, toland, than, see, which,
# Nearest to as: produce, when, xy, reinsurance, moderately, consumerism, unto, heterotic,
# Nearest to time: year, way, day, cod, desk, case, period, rie,
# Nearest to some: many, several, these, various, any, most, their, all,
# Nearest to an: miscarriage, bulls, dewitt, linguists, wakefulness, huygens, logistical, deficient,
# Nearest to two: four, three, five, six, eight, seven, one, nine,
# Nearest to into: through, from, toward, under, fist, stephane, bernardino, megas,
# Nearest to many: some, several, various, these, both, those, such, other,
# Nearest to when: if, where, although, while, before, after, during, though,
# Nearest to no: valuation, any, sunlight, budgetary, little, carta, nothing, biafra,
# Average loss at step 62000: 3.237809
# Average loss at step 64000: 3.256159
# Average loss at step 66000: 3.401606
# Average loss at step 68000: 3.398790
# Average loss at step 70000: 3.356560
# Nearest to all: many, some, most, both, any, every, those, these,
# Nearest to years: days, months, centuries, minutes, year, decades, times, weeks,
# Nearest to such: these, known, well, many, yalta, some, including, unfamiliar,
# Nearest to about: around, over, ozarks, on, cock, hydro, stabilizer, emigr,
# Nearest to that: which, what, however, but, actually, this, often, climatic,
# Nearest to or: and, than, tactical, while, any, the, biafra, dialectical,
# Nearest to but: however, although, though, which, primality, and, whereas, that,
# Nearest to as: like, when, vend, xy, reinsurance, blackwell, how, consumerism,
# Nearest to time: desk, cod, way, case, hava, period, instance, year,
# Nearest to some: many, several, these, all, most, various, any, the,
# Nearest to an: miscarriage, dewitt, the, bulls, logistical, wakefulness, brandeis, linguists,
# Nearest to two: three, six, four, seven, one, five, eight, zero,
# Nearest to into: through, from, fist, toward, stephane, buckminsterfullerene, phalanx, cabbie,
# Nearest to many: some, several, various, these, all, most, those, such,
# Nearest to when: if, where, while, before, during, after, however, though,
# Nearest to no: any, valuation, little, carta, nothing, sunlight, there, biafra,
# Average loss at step 72000: 3.372237
# Average loss at step 74000: 3.350131
# Average loss at step 76000: 3.315294
# Average loss at step 78000: 3.353460
# Average loss at step 80000: 3.375893
# Nearest to all: both, many, every, various, any, several, each, some,
# Nearest to years: days, months, centuries, minutes, year, decades, weeks, times,
# Nearest to such: well, these, known, including, yalta, many, follows, politic,
# Nearest to about: around, over, stabilizer, filtering, paradigmatic, ozarks, spotting, cock,
# Nearest to that: which, however, what, often, actually, athelstan, but, lowly,
# Nearest to or: and, than, while, krzysztof, but, chrysler, ductus, eac,
# Nearest to but: however, although, though, and, than, while, whereas, which,
# Nearest to as: kryptonians, perturbations, before, serling, when, bukovina, dialectics, loon,
# Nearest to time: desk, rie, hava, prophecy, veganism, rgensen, instance, shreveport,
# Nearest to some: many, several, these, most, various, both, any, numerous,
# Nearest to an: miscarriage, undertook, rajah, wakefulness, linguists, dewitt, huygens, icebergs,
# Nearest to two: three, four, six, five, seven, one, eight, nine,
# Nearest to into: through, from, toward, lande, within, fist, phalanx, buckminsterfullerene,
# Nearest to many: some, several, various, these, both, most, all, those,
# Nearest to when: if, before, after, during, though, although, where, while,
# Nearest to no: little, nothing, valuation, carta, any, hmg, sulphate, zelazny,
# Average loss at step 82000: 3.405674
# Average loss at step 84000: 3.409239
# Average loss at step 86000: 3.390053
# Average loss at step 88000: 3.349470
# Average loss at step 90000: 3.363092
# Nearest to all: many, both, some, every, several, any, various, these,
# Nearest to years: days, months, minutes, centuries, decades, weeks, year, hours,
# Nearest to such: known, well, these, certain, follows, many, yalta, kinase,
# Nearest to about: around, over, filtering, ozarks, tallest, paradigmatic, on, partials,
# Nearest to that: which, however, what, collateral, hardwoods, successfully, but, inaccurate,
# Nearest to or: and, than, dialectical, aphelion, whiskers, eac, but, including,
# Nearest to but: however, although, and, though, he, while, she, aurangzeb,
# Nearest to as: swnt, ramos, smilga, ava, furies, safin, rooming, perturbations,
# Nearest to time: hava, desk, period, day, bruun, case, prophecy, rgensen,
# Nearest to some: many, several, these, most, any, all, both, various,
# Nearest to an: miscarriage, extrinsic, dewitt, rajah, desist, superoxide, undertook, logistical,
# Nearest to two: three, four, five, six, eight, seven, one, nine,
# Nearest to into: through, from, stephane, lande, fist, sidearm, megas, toward,
# Nearest to many: some, several, various, these, most, all, numerous, those,
# Nearest to when: if, before, while, although, after, though, where, during,
# Nearest to no: little, any, nothing, valuation, carta, only, sulphate, hmg,
# Average loss at step 92000: 3.397716
# Average loss at step 94000: 3.260117
# Average loss at step 96000: 3.358777
# Average loss at step 98000: 3.242824
# Average loss at step 100000: 3.354234
# Nearest to all: many, every, some, both, several, these, various, any,
# Nearest to years: days, months, minutes, year, decades, centuries, weeks, hours,
# Nearest to such: known, well, these, many, follows, yalta, certain, including,
# Nearest to about: around, over, approached, ozarks, phenomenological, stabilizer, paradigmatic, penis,
# Nearest to that: which, however, what, lenny, who, but, earning, sutherland,
# Nearest to or: and, than, while, whiskers, ductus, like, unanimously, promising,
# Nearest to but: however, although, and, though, toland, which, while, cheered,
# Nearest to as: furies, longfellow, lifeson, when, swnt, enmity, sidon, winds,
# Nearest to time: desk, day, year, veganism, period, case, rgensen, bruun,
# Nearest to some: many, several, these, any, all, certain, various, their,
# Nearest to an: miscarriage, bulls, wakefulness, scilly, rajah, unconditional, elmendorf, logistical,
# Nearest to two: three, four, five, six, seven, eight, one, nine,
# Nearest to into: through, from, fist, within, toward, lande, connick, fascists,
# Nearest to many: several, some, various, these, numerous, all, those, few,
# Nearest to when: if, while, before, although, after, though, where, during,
# Nearest to no: little, any, valuation, carta, nothing, branded, sulphate, hmg,

# %%
num_points = 400

tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000)
two_d_embeddings = tsne.fit_transform(final_embeddings[1:num_points+1, :])

# %%
def plot(embeddings, labels):
  assert embeddings.shape[0] >= len(labels), 'More labels than embeddings'
  pylab.figure(figsize=(15,15))  # in inches
  for i, label in enumerate(labels):
    x, y = embeddings[i,:]
    pylab.scatter(x, y)
    pylab.annotate(label, xy=(x, y), xytext=(5, 2), textcoords='offset points',
                   ha='right', va='bottom')
  pylab.show()

words = [reverse_dictionary[i] for i in range(1, num_points+1)]
plot(two_d_embeddings, words)

# %% [markdown]
# ---
#
# Problem
# -------
#
# An alternative to skip-gram is another Word2Vec model called [CBOW](http://arxiv.org/abs/1301.3781) (Continuous Bag of Words). In the CBOW model, instead of predicting a context word from a word vector, you predict a word from the sum of all the word vectors in its context. Implement and evaluate a CBOW model trained on the text8 dataset.
#
# ---
